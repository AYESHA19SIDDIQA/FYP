# %%
import sys
print(sys.executable)
print(sys.path)
# Out:
# C:\Program Files\Python312\python.exe
# ['C:\\Program Files\\Python312\\python312.zip', 'C:\\Program Files\\Python312\\DLLs', 'C:\\Program Files\\Python312\\Lib', 'C:\\Program Files\\Python312', '', 'C:\\Users\\hp\\AppData\\Roaming\\Python\\Python312\\site-packages', 'C:\\Users\\hp\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32', 'C:\\Users\\hp\\AppData\\Roaming\\Python\\Python312\\site-packages\\win32\\lib', 'C:\\Users\\hp\\AppData\\Roaming\\Python\\Python312\\site-packages\\Pythonwin', 'C:\\Program Files\\Python312\\Lib\\site-packages', 'C:\\Program Files\\Python312\\Lib\\site-packages\\vboxapi-1.0-py3.12.egg']

# %%
# !pip install torchmetrics
# Out:
# Requirement already satisfied: torchmetrics in d:\athar_code\venv\lib\site-packages (1.8.2)
# Requirement already satisfied: numpy>1.20.0 in d:\athar_code\venv\lib\site-packages (from torchmetrics) (2.3.5)
# Requirement already satisfied: packaging>17.1 in d:\athar_code\venv\lib\site-packages (from torchmetrics) (25.0)
# Requirement already satisfied: torch>=2.0.0 in d:\athar_code\venv\lib\site-packages (from torchmetrics) (2.9.1)
# Requirement already satisfied: lightning-utilities>=0.8.0 in d:\athar_code\venv\lib\site-packages (from torchmetrics) (0.15.2)
# Requirement already satisfied: setuptools in d:\athar_code\venv\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (68.0.0)
# Requirement already satisfied: typing_extensions in d:\athar_code\venv\lib\site-packages (from lightning-utilities>=0.8.0->torchmetrics) (4.15.0)
# Requirement already satisfied: filelock in d:\athar_code\venv\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.20.0)
# Requirement already satisfied: sympy>=1.13.3 in d:\athar_code\venv\lib\site-packages (from torch>=2.0.0->torchmetrics) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in d:\athar_code\venv\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.6)
# Requirement already satisfied: jinja2 in d:\athar_code\venv\lib\site-packages (from torch>=2.0.0->torchmetrics) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in d:\athar_code\venv\lib\site-packages (from torch>=2.0.0->torchmetrics) (2025.10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in d:\athar_code\venv\lib\site-packages (from sympy>=1.13.3->torch>=2.0.0->torchmetrics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\athar_code\venv\lib\site-packages (from jinja2->torch>=2.0.0->torchmetrics) (3.0.3)
# [notice] A new release of pip is available: 23.2.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import torch
from torch import nn
from torch.nn import functional as F
from torch.utils.data import DataLoader
from cereprocess.train.xloop import oneloop, get_datanpz, get_dataloaders
from cereprocess.train.misc import TrainElements, get_model_size, EarlyStopping, check_model, def_dev, def_hyp
from cereprocess.datasets.defaults import get_def_ds
from cereprocess.datasets.pytordataset import KFoldDataset
from cereprocess.datasets.pipeline import general_pipeline
from cereprocess.train.retrieve import load_picks, get_results                
from cereprocess.train.train import evaluate          
from cereprocess.train.callbacks import def_metrics       
from cereprocess.datasets.pytordataset import KFoldDataset

import pandas as pd
import numpy as np
import gc
import os

# %% [markdown]
# # Training

# %%
device = def_dev()
mins = 5
length = mins * 3000
input_size = (22, length)
tuh, nmt, nmt_4k = get_def_ds(mins)

# %%
# Change the dataset currently in use from over here
curr_data = nmt_4k

# %%
from cereprocess.datasets.getfiles import get_files
dataset_path = "E:/NMT_events/NMT_events/edf"

train, eval_ = get_files(dataset_path)

print("Train Normal:", len(train["normal"]))
print("Train Abnormal:", len(train["abnormal"]))
print("Eval Normal:", len(eval_["normal"]))
print("Eval Abnormal:", len(eval_["abnormal"]))
# Out:
#   Cell In[7], line 2
#     dataset_path = "E:\NMT_events\NMT_events\edf"
#                    ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: malformed \N character escape

# %%
# Change pipeline from here
data_dir, data_description = get_datanpz(curr_data[0], curr_data[3], general_pipeline(dataset='NMT', length_minutes=mins), input_size)
# Out:
# Saving Data to Numpy Files
# Converting train files
# Total Pipelines: 1
# Total Normal Files: 80
# Total Abnormal Files: 80
# Converting Normal Files
# Processing Normal files:   0%|          | 0/80 [00:00<?, ?it/s]
# Creating RawArray with float64 data, n_channels=22, n_times=57700
#     Range : 0 ... 57699 =      0.000 ...  1153.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=60700
#     Range : 0 ... 60699 =      0.000 ...  1213.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=43100
#     Range : 0 ... 43099 =      0.000 ...   861.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=57900
#     Range : 0 ... 57899 =      0.000 ...  1157.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=61200
#     Range : 0 ... 61199 =      0.000 ...  1223.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=65400
#     Range : 0 ... 65399 =      0.000 ...  1307.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=61600
#     Range : 0 ... 61599 =      0.000 ...  1231.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64400
#     Range : 0 ... 64399 =      0.000 ...  1287.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=62300
#     Range : 0 ... 62299 =      0.000 ...  1245.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=49800
#     Range : 0 ... 49799 =      0.000 ...   995.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64100
#     Range : 0 ... 64099 =      0.000 ...  1281.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=59900
#     Range : 0 ... 59899 =      0.000 ...  1197.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64800
#     Range : 0 ... 64799 =      0.000 ...  1295.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=36600
#     Range : 0 ... 36599 =      0.000 ...   731.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64000
#     Range : 0 ... 63999 =      0.000 ...  1279.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=60900
#     Range : 0 ... 60899 =      0.000 ...  1217.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=65600
#     Range : 0 ... 65599 =      0.000 ...  1311.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=55300
#     Range : 0 ... 55299 =      0.000 ...  1105.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=54400
#     Range : 0 ... 54399 =      0.000 ...  1087.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64800
#     Range : 0 ... 64799 =      0.000 ...  1295.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=44300
#     Range : 0 ... 44299 =      0.000 ...   885.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=57800
#     Range : 0 ... 57799 =      0.000 ...  1155.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=58100
#     Range : 0 ... 58099 =      0.000 ...  1161.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=43200
#     Range : 0 ... 43199 =      0.000 ...   863.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=59500
#     Range : 0 ... 59499 =      0.000 ...  1189.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=52000
#     Range : 0 ... 51999 =      0.000 ...  1039.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=57800
#     Range : 0 ... 57799 =      0.000 ...  1155.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=42100
#     Range : 0 ... 42099 =      0.000 ...   841.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=58200
#     Range : 0 ... 58199 =      0.000 ...  1163.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=57900
#     Range : 0 ... 57899 =      0.000 ...  1157.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=46100
#     Range : 0 ... 46099 =      0.000 ...   921.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=57400
#     Range : 0 ... 57399 =      0.000 ...  1147.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=55500
#     Range : 0 ... 55499 =      0.000 ...  1109.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=61600
#     Range : 0 ... 61599 =      0.000 ...  1231.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=59100
#     Range : 0 ... 59099 =      0.000 ...  1181.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=61900
#     Range : 0 ... 61899 =      0.000 ...  1237.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=60700
#     Range : 0 ... 60699 =      0.000 ...  1213.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=30800
#     Range : 0 ... 30799 =      0.000 ...   615.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=61600
#     Range : 0 ... 61599 =      0.000 ...  1231.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=52800
#     Range : 0 ... 52799 =      0.000 ...  1055.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=54700
#     Range : 0 ... 54699 =      0.000 ...  1093.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=39800
#     Range : 0 ... 39799 =      0.000 ...   795.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=39700
#     Range : 0 ... 39699 =      0.000 ...   793.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=59600
#     Range : 0 ... 59599 =      0.000 ...  1191.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=48700
#     Range : 0 ... 48699 =      0.000 ...   973.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=61900
#     Range : 0 ... 61899 =      0.000 ...  1237.980 secs
# Ready.
# Converting Abnormal Files
# Processing Abnormal files:   0%|          | 0/80 [00:00<?, ?it/s]
# Creating RawArray with float64 data, n_channels=22, n_times=59400
#     Range : 0 ... 59399 =      0.000 ...  1187.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=60000
#     Range : 0 ... 59999 =      0.000 ...  1199.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64800
#     Range : 0 ... 64799 =      0.000 ...  1295.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64400
#     Range : 0 ... 64399 =      0.000 ...  1287.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=55800
#     Range : 0 ... 55799 =      0.000 ...  1115.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=54000
#     Range : 0 ... 53999 =      0.000 ...  1079.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=54000
#     Range : 0 ... 53999 =      0.000 ...  1079.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=57300
#     Range : 0 ... 57299 =      0.000 ...  1145.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=63800
#     Range : 0 ... 63799 =      0.000 ...  1275.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64600
#     Range : 0 ... 64599 =      0.000 ...  1291.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=60000
#     Range : 0 ... 59999 =      0.000 ...  1199.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=52200
#     Range : 0 ... 52199 =      0.000 ...  1043.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=49100
#     Range : 0 ... 49099 =      0.000 ...   981.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=45600
#     Range : 0 ... 45599 =      0.000 ...   911.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64300
#     Range : 0 ... 64299 =      0.000 ...  1285.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=54000
#     Range : 0 ... 53999 =      0.000 ...  1079.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=63000
#     Range : 0 ... 62999 =      0.000 ...  1259.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=48600
#     Range : 0 ... 48599 =      0.000 ...   971.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=52700
#     Range : 0 ... 52699 =      0.000 ...  1053.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=32000
#     Range : 0 ... 31999 =      0.000 ...   639.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64000
#     Range : 0 ... 63999 =      0.000 ...  1279.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=49200
#     Range : 0 ... 49199 =      0.000 ...   983.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=38900
#     Range : 0 ... 38899 =      0.000 ...   777.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=48000
#     Range : 0 ... 47999 =      0.000 ...   959.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=47300
#     Range : 0 ... 47299 =      0.000 ...   945.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=45500
#     Range : 0 ... 45499 =      0.000 ...   909.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=63700
#     Range : 0 ... 63699 =      0.000 ...  1273.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64700
#     Range : 0 ... 64699 =      0.000 ...  1293.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=55600
#     Range : 0 ... 55599 =      0.000 ...  1111.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=42300
#     Range : 0 ... 42299 =      0.000 ...   845.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=48100
#     Range : 0 ... 48099 =      0.000 ...   961.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=65900
#     Range : 0 ... 65899 =      0.000 ...  1317.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=62600
#     Range : 0 ... 62599 =      0.000 ...  1251.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=42900
#     Range : 0 ... 42899 =      0.000 ...   857.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=61000
#     Range : 0 ... 60999 =      0.000 ...  1219.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=43900
#     Range : 0 ... 43899 =      0.000 ...   877.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=48900
#     Range : 0 ... 48899 =      0.000 ...   977.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=42400
#     Range : 0 ... 42399 =      0.000 ...   847.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=48000
#     Range : 0 ... 47999 =      0.000 ...   959.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=56600
#     Range : 0 ... 56599 =      0.000 ...  1131.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=54100
#     Range : 0 ... 54099 =      0.000 ...  1081.980 secs
# Ready.
# CSV saved to results/nmt4k\data\data_processed\results0\train\data.csv
# Converting eval files
# Total Pipelines: 1
# Total Normal Files: 10
# Total Abnormal Files: 10
# Converting Normal Files
# Processing Normal files:   0%|          | 0/10 [00:00<?, ?it/s]
# Creating RawArray with float64 data, n_channels=22, n_times=61200
#     Range : 0 ... 61199 =      0.000 ...  1223.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=59400
#     Range : 0 ... 59399 =      0.000 ...  1187.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=58700
#     Range : 0 ... 58699 =      0.000 ...  1173.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=52800
#     Range : 0 ... 52799 =      0.000 ...  1055.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=64600
#     Range : 0 ... 64599 =      0.000 ...  1291.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=58500
#     Range : 0 ... 58499 =      0.000 ...  1169.980 secs
# Ready.
# Converting Abnormal Files
# Processing Abnormal files:   0%|          | 0/10 [00:00<?, ?it/s]
# Creating RawArray with float64 data, n_channels=22, n_times=54500
#     Range : 0 ... 54499 =      0.000 ...  1089.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=49200
#     Range : 0 ... 49199 =      0.000 ...   983.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=55400
#     Range : 0 ... 55399 =      0.000 ...  1107.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=45800
#     Range : 0 ... 45799 =      0.000 ...   915.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=50000
#     Range : 0 ... 49999 =      0.000 ...   999.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=49300
#     Range : 0 ... 49299 =      0.000 ...   985.980 secs
# Ready.
# Creating RawArray with float64 data, n_channels=22, n_times=48100
#     Range : 0 ... 48099 =      0.000 ...   961.980 secs
# Ready.
# CSV saved to results/nmt4k\data\data_processed\results0\eval\data.csv
# CSV saved to results/nmt4k\data\data_processed\results0\data.csv
# ('results/nmt4k\\data\\data_processed\\results0', 50, 600, 22, 'results0')
# Saving Data to Numpy Files
# Data Already Stored

# %%
# Start training from here
# Set hyperparameters
seed=42
hyps = def_hyp(batch_size=8, epochs=10, lr=0.0003, accum_iter=1)
train_loader, eval_loader = get_dataloaders(data_dir, hyps['batch_size'], target_length=length,seed=seed)
# Set early stopping
es = EarlyStopping(patience=60) 
# Configure training
train_elems = TrainElements(device
, earlystopping=es
)
model = NeuroGATE().to(device)
name = f'NeuroGate'
model_x = oneloop(device, model, train_loader, eval_loader, data_description, hyps, train_elems, curr_data[3], name)
torch.cuda.empty_cache()
gc.collect()
# Out:
# Printing Best:
# Loss Wise:
# Best Loss: 0.7116995503505071
# {'loss': 0.7116995503505071, 'accuracy': 0.5263158082962036, 'precision': 0.5, 'recall': 0.3333333432674408, 'f1score': 0.4000000059604645, 'auroc': 0.5166666507720947, 'specificity': 0.699999988079071}
# Best Accuracy: 0.5263158082962036
# {'accuracy': 0.5263158082962036, 'precision': 0.5, 'recall': 0.3333333432674408, 'f1score': 0.4000000059604645, 'auroc': 0.5166666507720947, 'specificity': 0.699999988079071, 'loss': 0.7116995503505071}
# 38875

# %% [markdown]
# # Evaluating a trained model

# %%
metrics = def_metrics(device)
model = NeuroGATE().to(device)
model.load_state_dict(torch.load("results/nmt4k/models/model_1.pt"))
train_elems = TrainElements(device)

# %%
length = 10 * 3000
hyps = def_hyp(batch_size=8, epochs=60, lr=0.0003, accum_iter=1)
train_loader, eval_loader = get_dataloaders(data_dir, hyps['batch_size'], target_length=length,seed=42)

# %%
evaluate(model, eval_loader, train_elems.criterion, device, metrics, train_elems.history, plot_roc=False)
# Out:
# D:\athar_code\venv\Lib\site-packages\torch\nn\functional.py:1538: UserWarning: dropout2d: Received a 3D input to dropout2d and assuming that channel-wise 1D dropout behavior is desired - input is interpreted as shape (N, C, L), where C is the channel dim. This behavior will change in a future release to interpret the input as one without a batch dimension, i.e. shape (C, H, W). To maintain the 1D channel-wise dropout behavior, please switch to using dropout1d instead.
#   warnings.warn(
# 0.7116995503505071

# %%
train_elems.history.history
# Out:
# {'train': {},
#  'val': {'accuracy': [0.5263158082962036, 0.5263158082962036],
#   'precision': [0.5, 0.5],
#   'recall': [0.3333333432674408, 0.3333333432674408],
#   'f1score': [0.4000000059604645, 0.4000000059604645],
#   'auroc': [0.5166666507720947, 0.5166666507720947],
#   'specificity': [0.699999988079071, 0.699999988079071],
#   'loss': [0.7116995503505071, 0.7116995503505071]}}

# %%
{key: value[-1] if isinstance(value, list) else value for key, value in history.history['val'].items()}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 {key: value[-1] if isinstance(value, list) else value for key, value in history.history['val'].items()}
#
# NameError: name 'history' is not defined

# %% [markdown]
# # Running K-Fold Training

# %%
i = 1
for trainset, evalset in KFoldDataset(root_dir=data_dir, n_splits=10, shuffle=True):
    train_loader = DataLoader(trainset, batch_size=hyps["batch_size"], shuffle=True)
    eval_loader = DataLoader(evalset)
    model = NeuroGATE().to(device)
    train_elems = TrainElements(device)
    name = f'KFold-{i}'
    model_x = oneloop(device, model, train_loader, eval_loader, data_description, hyps, train_elems, curr_data[3], name)
    torch.cuda.empty_cache()
    gc.collect()
    i += 1
# Out:
# EarlyStopping counter: 2 out of 10
# Epoch 18/60 - Train Loss: 0.6828 - Val Loss: 0.3377
# Train Accuracy: 0.6357 - Val Accuracy: 0.9333
# Train F1 Score: 0.6466 - Val F1 Score: 0.9333
#
# Printing Best:
# Loss Wise:
# Best Loss: 0.27367354879776634
# {'loss': 0.27367354879776634, 'accuracy': 0.9333333373069763, 'precision': 1.0, 'recall': 0.8571428656578064, 'f1score': 0.9230769276618958, 'auroc': 0.9285714626312256, 'specificity': 1.0}
# Best Accuracy: 0.9333333373069763
# {'accuracy': 0.9333333373069763, 'precision': 0.875, 'recall': 1.0, 'f1score': 0.9333333373069763, 'auroc': 0.9375, 'specificity': 0.875, 'loss': 0.4321183145046234}
#   0%|          | 0/17 [00:00<?, ?it/s]

# %% [markdown]
# # Check Results

# %%
from train.retrieve import get_results, get_paths, load_picks
import pickle
from datasets.defaults import get_def_ds

# %%
# Defining the dataset (This stores information for tuh and nmt, including the class weight balancing)
tuh, nmt, nmt_4k = get_def_ds(mins=mins)
current_selected = nmt_4k

# %%
res = get_results(current_selected[3], clean=True)

# %%
res.head()
